# %%
import pandas as pd
df = pd.read_csv('dataset_new.csv')
fulldf = pd.read_csv('data/data.csv')
failed = pd.read_csv('failed_new.csv')
print("{} out of {} rows completed. {} failed".format(len(df), len(fulldf), len(failed)))
# Out:
# 226 out of 420464 rows completed. 0 failed

# %%
df
# Out:
#            hosted_from                                         name  \
# 0       104.27.130.151                            DNC Holdings, Inc
# 1       23.227.173.218                  Moniker Online Services LLC
# 2      107.151.161.219  Alibaba Cloud Computing (Beijing) Co., Ltd.
# 3           5.9.82.114                                 1&1 IONOS SE
# 4       91.195.240.126        TurnCommerce, Inc. DBA NameBright.com
# ...                ...                                          ...
# 14410     50.63.202.57                             GoDaddy.com, LLC
# 14411     50.63.202.57                             GoDaddy.com, LLC
# 14412    143.95.233.16                                   ENOM, INC.
# 14413    143.95.233.16                                   ENOM, INC.
# 14414  192.186.252.161                             GoDaddy.com, LLC
#
#              whois_nameservers country_tld                  domain  \
# 0      NELLY.NS.CLOUDFLARE.COM         com          tubemoviez.com
# ...

# %%
import pandas_profiling

# %%
df.profile_report(style={'full_width':True})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-d38b0259845d> in <module>
# ----> 1 df.profile_report(style={'full_width':True})
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'
